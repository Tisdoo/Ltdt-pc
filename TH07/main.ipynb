# %% [markdown]
# # Bài 1

# %% [markdown]
# Main idea: Là 1 đồ thị liên thông và không có chu trình(có n-1 cạnh). Với Số node của đồ thị bằng số nút của cây khung và cạnh của cây khung là con của cạnh đồ thị.
#  Tạo 1 vector visited để xét đã thăm hay chưa.
#  Xét mọi đỉnh v chưa được thăm kề u bằng DFS.

# %%
# !cat test1.inp
# Out:
# 6 6
# 1 2
# 1 3
# 1 6
# 2 4
# 2 5
# 5 6

# %%
# !./CaykhungDFS < test1.inp > output1.txt
# !cat output1.txt
# Out:
# 5
# 1 2
# 2 4
# 2 5
# 5 6
# 1 3

# %% [markdown]
# # Bài 2

# %% [markdown]
# Main idea:
